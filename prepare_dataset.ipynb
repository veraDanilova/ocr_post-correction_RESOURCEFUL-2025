# %%
import os
import json
import pandas as pd
import Levenstein
import re
import edlib
import codecs
import itertools
from bs4 import BeautifulSoup
from extract_text import *

# %% [markdown]
# ## Get ICDAR data (aligned)

# %%
! wget --no-check-certificate -O "ICDAR2019-POCR-ground-truth.zip" "https://zenodo.org/records/3515403/files/ICDAR2019-POCR-ground-truth.zip?download=1"
# Out:
# --2025-02-05 13:02:43--  https://zenodo.org/records/3515403/files/ICDAR2019-POCR-ground-truth.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54341904 (52M) [application/octet-stream]
# Saving to: ‘ICDAR2019-POCR-ground-truth.zip’
#
# ICDAR2019-POCR-grou 100%[===================>]  51,82M  26,8MB/s    in 1,9s
#
# 2025-02-05 13:02:45 (26,8 MB/s) - ‘ICDAR2019-POCR-ground-truth.zip’ saved [54341904/54341904]

# %%
! unzip -o "ICDAR2019-POCR-ground-truth.zip"
# Out:
# Archive:  ICDAR2019-POCR-ground-truth.zip
#    creating: evaluation_4M_without_Finnish/
#    creating: evaluation_4M_without_Finnish/BG/
#    creating: evaluation_4M_without_Finnish/BG/BG1/
#   inflating: evaluation_4M_without_Finnish/BG/BG1/1.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/0.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/2.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/3.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/4.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/5.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/6.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/7.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/8.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/9.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/10.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/11.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/12.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/13.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/14.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/15.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/16.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/17.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/18.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/19.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/20.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/21.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/22.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/23.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/24.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/25.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/26.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/27.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/28.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/29.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/30.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/31.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/32.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/33.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/35.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/36.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/37.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/38.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/39.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/40.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/41.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/42.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/43.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/44.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/45.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/46.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/47.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/48.txt
#   inflating: evaluation_4M_without_Finnish/BG/BG1/49.txt
#    creating: evaluation_4M_without_Finnish/CZ/
#    creating: evaluation_4M_without_Finnish/CZ/CZ1/
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/1.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/0.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/2.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/3.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/4.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/5.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/6.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/7.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/8.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/9.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/10.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/11.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/12.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/13.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/14.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/15.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/16.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/17.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/18.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/19.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/20.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/21.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/22.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/23.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/24.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/25.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/26.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/27.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/28.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/29.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/30.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/31.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/32.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/33.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/34.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/35.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/36.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/37.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/38.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/39.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/40.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/41.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/42.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/43.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/44.txt
#   inflating: evaluation_4M_without_Finnish/CZ/CZ1/45.txt
#    creating: evaluation_4M_without_Finnish/DE/
#    creating: evaluation_4M_without_Finnish/DE/DE1/
#   inflating: evaluation_4M_without_Finnish/DE/DE1/0.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/1.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/10.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/11.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/12.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/13.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/14.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/15.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/16.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/17.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/18.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/19.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/2.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/3.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/4.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/5.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/6.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/7.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/8.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/9.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE1/.11.txt.~70da7033
#   inflating: evaluation_4M_without_Finnish/DE/DE1/.12.txt.~471449ab
#    creating: evaluation_4M_without_Finnish/DE/DE2/
#   inflating: evaluation_4M_without_Finnish/DE/DE2/1.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/2.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/0.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/3.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/4.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/5.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/6.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/7.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/8.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/9.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/10.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/11.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/12.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/13.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/14.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/15.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/16.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/17.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/18.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/19.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/20.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/21.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/22.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/23.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/24.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/25.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/26.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/27.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/28.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/29.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/30.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/31.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/32.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/33.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/34.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/35.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/36.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/37.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/38.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/39.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/40.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/41.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/42.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/43.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/44.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/45.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/46.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/47.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/48.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE2/49.txt
#    creating: evaluation_4M_without_Finnish/DE/DE3/
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1013.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1031.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1050.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1054.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1055.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1056.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1058.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1063.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1064.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1066.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/107.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1071.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1073.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1075.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/108.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1080.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1081.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1082.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1083.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1084.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1088.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1089.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1090.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1092.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1097.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1098.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1099.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1101.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1103.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1106.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1107.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1113.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1114.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1115.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1118.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1121.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1122.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1125.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1128.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1129.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/113.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1130.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1132.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1133.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1134.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1135.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1141.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1142.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1147.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1149.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1150.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1154.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1158.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1159.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1161.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1162.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1165.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1172.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1177.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1178.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1179.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1180.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1182.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1183.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1185.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1186.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1189.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1190.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1191.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1195.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1197.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/12.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/120.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1201.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1204.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1205.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1208.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1211.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1212.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1213.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1214.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1218.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1220.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1222.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1224.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1228.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1230.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1235.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1236.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1238.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/124.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1241.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1242.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1243.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1244.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1245.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1246.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1247.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/125.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1251.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1253.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1254.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1255.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1259.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/126.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1266.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1268.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1269.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/127.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1274.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1276.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1277.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1278.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/128.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1280.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1281.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1283.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1285.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1287.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1289.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/129.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1290.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1291.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1293.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1294.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/13.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1301.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1304.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1305.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1310.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1313.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1316.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1317.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1326.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1334.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1337.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1338.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1341.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1342.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1343.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1344.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1346.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1348.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1349.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/135.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1351.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1352.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1354.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1357.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1358.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1359.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1360.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1361.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1368.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1369.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1371.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1372.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1378.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1385.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1390.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1392.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1393.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1395.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1396.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/140.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1401.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1403.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1405.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1406.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1409.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1411.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1415.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1419.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/142.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1421.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1422.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1426.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1427.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1428.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/143.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1431.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1433.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1434.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1435.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1439.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1442.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1443.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1445.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1446.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1449.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/145.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1453.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1454.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1455.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1458.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1459.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1463.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1469.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/147.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1474.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1476.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1478.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/148.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1486.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1487.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/149.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1493.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1497.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1498.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1499.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/15.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/150.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1500.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1501.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1503.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1508.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/151.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1513.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1517.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1519.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/152.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1523.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1524.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/153.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/156.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/158.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/159.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/161.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/166.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/169.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/172.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/173.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/175.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/179.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/182.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/183.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/187.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/189.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/193.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/196.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/197.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/199.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/2.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/20.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/202.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/206.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/207.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/21.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/212.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/213.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/217.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/220.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/221.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/222.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/223.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/225.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/23.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/231.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/232.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/235.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/239.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/240.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/242.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/243.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/245.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/246.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/247.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/248.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/250.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/251.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/255.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/257.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/258.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/26.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/260.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/261.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/263.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/265.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/267.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/268.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/271.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/273.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/275.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/277.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/278.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/279.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/281.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/282.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/283.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/285.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/286.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/287.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/289.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/292.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/293.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/294.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/295.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/296.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/297.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/299.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/30.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/301.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/302.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/303.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/305.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/307.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/309.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/31.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/312.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/313.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/314.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/315.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/319.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/320.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/321.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/328.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/330.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/332.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/336.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/34.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/341.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/343.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/344.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/345.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/347.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/349.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/351.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/352.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/354.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/355.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/356.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/359.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/363.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/367.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/37.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/370.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/373.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/374.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/379.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/381.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/385.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/39.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/392.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/397.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/398.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/399.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/40.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/400.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/402.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/403.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/405.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/406.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/409.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/412.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/413.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/415.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/417.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/418.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/420.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/421.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/428.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/43.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/434.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/436.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/437.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/439.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/44.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/443.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/444.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/446.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/449.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/45.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/454.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/455.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/457.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/459.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/46.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/468.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/469.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/470.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/471.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/474.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/477.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/484.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/487.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/488.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/49.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/490.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/491.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/492.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/493.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/494.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/496.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/498.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/500.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/506.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/508.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/509.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/51.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/510.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/513.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/514.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/519.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/52.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/528.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/529.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/53.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/531.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/532.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/533.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/535.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/537.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/538.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/540.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/541.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/0.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/100.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1000.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1001.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1004.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1005.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1008.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1012.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1014.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1017.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1018.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/102.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1020.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1025.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1026.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1027.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1030.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1518.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/523.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/542.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1034.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1036.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1037.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/104.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1041.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1042.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/1047.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/391.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/41.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/448.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/467.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/544.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/545.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/547.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/549.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/55.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/550.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/551.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/553.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/554.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/558.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/56.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/562.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/564.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/567.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/569.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/572.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/574.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/578.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/579.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/58.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/585.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/586.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/589.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/59.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/590.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/591.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/593.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/596.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/598.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/6.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/601.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/604.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/606.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/607.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/608.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/619.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/62.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/623.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/624.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/627.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/628.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/630.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/634.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/637.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/645.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/646.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/647.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/648.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/649.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/650.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/652.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/653.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/655.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/656.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/657.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/658.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/659.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/66.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/662.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/665.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/667.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/668.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/674.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/681.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/682.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/684.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/690.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/692.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/703.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/706.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/708.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/709.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/716.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/717.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/718.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/719.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/723.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/724.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/726.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/728.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/729.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/73.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/732.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/733.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/734.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/737.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/74.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/741.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/742.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/746.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/748.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/750.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/751.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/752.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/753.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/756.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/757.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/758.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/759.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/763.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/764.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/768.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/769.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/772.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/775.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/776.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/785.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/786.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/790.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/791.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/793.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/794.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/795.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/796.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/798.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/799.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/801.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/803.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/804.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/805.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/806.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/807.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/808.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/81.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/812.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/813.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/814.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/815.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/817.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/818.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/820.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/824.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/828.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/83.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/831.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/833.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/840.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/842.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/844.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/847.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/848.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/85.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/851.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/852.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/854.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/855.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/857.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/86.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/861.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/866.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/867.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/869.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/87.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/870.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/871.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/874.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/875.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/879.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/881.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/883.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/886.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/887.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/890.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/893.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/894.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/898.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/899.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/900.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/902.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/903.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/907.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/909.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/910.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/911.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/913.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/918.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/919.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/935.txt
#   inflating: evaluation_4M_without_Finnish/DE/DE3/940.txt
# ...
#   inflating: training_18M_without_Finnish/PL/PL1/26.txt
#   inflating: training_18M_without_Finnish/PL/PL1/27.txt
#   inflating: training_18M_without_Finnish/PL/PL1/28.txt
#   inflating: training_18M_without_Finnish/PL/PL1/29.txt
#   inflating: training_18M_without_Finnish/PL/PL1/30.txt
#   inflating: training_18M_without_Finnish/PL/PL1/31.txt
#   inflating: training_18M_without_Finnish/PL/PL1/32.txt
#   inflating: training_18M_without_Finnish/PL/PL1/33.txt
#   inflating: training_18M_without_Finnish/PL/PL1/34.txt
#   inflating: training_18M_without_Finnish/PL/PL1/35.txt
#   inflating: training_18M_without_Finnish/PL/PL1/36.txt
#   inflating: training_18M_without_Finnish/PL/PL1/37.txt
#   inflating: training_18M_without_Finnish/PL/PL1/38.txt
#   inflating: training_18M_without_Finnish/PL/PL1/39.txt
#   inflating: training_18M_without_Finnish/PL/PL1/40.txt
#   inflating: training_18M_without_Finnish/PL/PL1/41.txt
#   inflating: training_18M_without_Finnish/PL/PL1/42.txt
#   inflating: training_18M_without_Finnish/PL/PL1/43.txt
#   inflating: training_18M_without_Finnish/PL/PL1/44.txt
#   inflating: training_18M_without_Finnish/PL/PL1/45.txt
#   inflating: training_18M_without_Finnish/PL/PL1/46.txt
#   inflating: training_18M_without_Finnish/PL/PL1/47.txt
#   inflating: training_18M_without_Finnish/PL/PL1/48.txt
#   inflating: training_18M_without_Finnish/PL/PL1/49.txt
#   inflating: training_18M_without_Finnish/PL/PL1/50.txt
#   inflating: training_18M_without_Finnish/PL/PL1/51.txt
#   inflating: training_18M_without_Finnish/PL/PL1/52.txt
#   inflating: training_18M_without_Finnish/PL/PL1/53.txt
#   inflating: training_18M_without_Finnish/PL/PL1/54.txt
#   inflating: training_18M_without_Finnish/PL/PL1/55.txt
#   inflating: training_18M_without_Finnish/PL/PL1/56.txt
#   inflating: training_18M_without_Finnish/PL/PL1/57.txt
#   inflating: training_18M_without_Finnish/PL/PL1/58.txt
#   inflating: training_18M_without_Finnish/PL/PL1/59.txt
#   inflating: training_18M_without_Finnish/PL/PL1/60.txt
#   inflating: training_18M_without_Finnish/PL/PL1/61.txt
#   inflating: training_18M_without_Finnish/PL/PL1/62.txt
#   inflating: training_18M_without_Finnish/PL/PL1/63.txt
#   inflating: training_18M_without_Finnish/PL/PL1/64.txt
#   inflating: training_18M_without_Finnish/PL/PL1/65.txt
#   inflating: training_18M_without_Finnish/PL/PL1/66.txt
#   inflating: training_18M_without_Finnish/PL/PL1/67.txt
#   inflating: training_18M_without_Finnish/PL/PL1/68.txt
#   inflating: training_18M_without_Finnish/PL/PL1/69.txt
#   inflating: training_18M_without_Finnish/PL/PL1/70.txt
#   inflating: training_18M_without_Finnish/PL/PL1/71.txt
#   inflating: training_18M_without_Finnish/PL/PL1/72.txt
#   inflating: training_18M_without_Finnish/PL/PL1/73.txt
#   inflating: training_18M_without_Finnish/PL/PL1/74.txt
#   inflating: training_18M_without_Finnish/PL/PL1/75.txt
#   inflating: training_18M_without_Finnish/PL/PL1/76.txt
#   inflating: training_18M_without_Finnish/PL/PL1/77.txt
#   inflating: training_18M_without_Finnish/PL/PL1/78.txt
#   inflating: training_18M_without_Finnish/PL/PL1/79.txt
#   inflating: training_18M_without_Finnish/PL/PL1/80.txt
#   inflating: training_18M_without_Finnish/PL/PL1/81.txt
#   inflating: training_18M_without_Finnish/PL/PL1/82.txt
#   inflating: training_18M_without_Finnish/PL/PL1/83.txt
#   inflating: training_18M_without_Finnish/PL/PL1/84.txt
#   inflating: training_18M_without_Finnish/PL/PL1/85.txt
#   inflating: training_18M_without_Finnish/PL/PL1/86.txt
#   inflating: training_18M_without_Finnish/PL/PL1/87.txt
#   inflating: training_18M_without_Finnish/PL/PL1/88.txt
#   inflating: training_18M_without_Finnish/PL/PL1/89.txt
#   inflating: training_18M_without_Finnish/PL/PL1/90.txt
#   inflating: training_18M_without_Finnish/PL/PL1/91.txt
#   inflating: training_18M_without_Finnish/PL/PL1/92.txt
#   inflating: training_18M_without_Finnish/PL/PL1/93.txt
#   inflating: training_18M_without_Finnish/PL/PL1/94.txt
#   inflating: training_18M_without_Finnish/PL/PL1/95.txt
#   inflating: training_18M_without_Finnish/PL/PL1/96.txt
#   inflating: training_18M_without_Finnish/PL/PL1/97.txt
#   inflating: training_18M_without_Finnish/PL/PL1/98.txt
#   inflating: training_18M_without_Finnish/PL/PL1/99.txt
#   inflating: training_18M_without_Finnish/PL/PL1/100.txt
#   inflating: training_18M_without_Finnish/PL/PL1/101.txt
#   inflating: training_18M_without_Finnish/PL/PL1/102.txt
#   inflating: training_18M_without_Finnish/PL/PL1/103.txt
#   inflating: training_18M_without_Finnish/PL/PL1/104.txt
#   inflating: training_18M_without_Finnish/PL/PL1/105.txt
#   inflating: training_18M_without_Finnish/PL/PL1/106.txt
#   inflating: training_18M_without_Finnish/PL/PL1/107.txt
#   inflating: training_18M_without_Finnish/PL/PL1/108.txt
#   inflating: training_18M_without_Finnish/PL/PL1/109.txt
#   inflating: training_18M_without_Finnish/PL/PL1/110.txt
#   inflating: training_18M_without_Finnish/PL/PL1/111.txt
#   inflating: training_18M_without_Finnish/PL/PL1/112.txt
#   inflating: training_18M_without_Finnish/PL/PL1/113.txt
#   inflating: training_18M_without_Finnish/PL/PL1/114.txt
#   inflating: training_18M_without_Finnish/PL/PL1/115.txt
#   inflating: training_18M_without_Finnish/PL/PL1/116.txt
#   inflating: training_18M_without_Finnish/PL/PL1/117.txt
#   inflating: training_18M_without_Finnish/PL/PL1/118.txt
#   inflating: training_18M_without_Finnish/PL/PL1/119.txt
#   inflating: training_18M_without_Finnish/PL/PL1/120.txt
#   inflating: training_18M_without_Finnish/PL/PL1/121.txt
#   inflating: training_18M_without_Finnish/PL/PL1/122.txt
#   inflating: training_18M_without_Finnish/PL/PL1/123.txt
#   inflating: training_18M_without_Finnish/PL/PL1/124.txt
#   inflating: training_18M_without_Finnish/PL/PL1/125.txt
#   inflating: training_18M_without_Finnish/PL/PL1/126.txt
#   inflating: training_18M_without_Finnish/PL/PL1/127.txt
#   inflating: training_18M_without_Finnish/PL/PL1/128.txt
#   inflating: training_18M_without_Finnish/PL/PL1/129.txt
#   inflating: training_18M_without_Finnish/PL/PL1/130.txt
#   inflating: training_18M_without_Finnish/PL/PL1/131.txt
#   inflating: training_18M_without_Finnish/PL/PL1/132.txt
#   inflating: training_18M_without_Finnish/PL/PL1/133.txt
#   inflating: training_18M_without_Finnish/PL/PL1/134.txt
#   inflating: training_18M_without_Finnish/PL/PL1/135.txt
#   inflating: training_18M_without_Finnish/PL/PL1/136.txt
#   inflating: training_18M_without_Finnish/PL/PL1/137.txt
#   inflating: training_18M_without_Finnish/PL/PL1/138.txt
#   inflating: training_18M_without_Finnish/PL/PL1/139.txt
#   inflating: training_18M_without_Finnish/PL/PL1/140.txt
#   inflating: training_18M_without_Finnish/PL/PL1/141.txt
#   inflating: training_18M_without_Finnish/PL/PL1/142.txt
#   inflating: training_18M_without_Finnish/PL/PL1/143.txt
#   inflating: training_18M_without_Finnish/PL/PL1/144.txt
#   inflating: training_18M_without_Finnish/PL/PL1/145.txt
#   inflating: training_18M_without_Finnish/PL/PL1/146.txt
#   inflating: training_18M_without_Finnish/PL/PL1/147.txt
#   inflating: training_18M_without_Finnish/PL/PL1/148.txt
#    creating: training_18M_without_Finnish/SL/
#    creating: training_18M_without_Finnish/SL/SL1/
#   inflating: training_18M_without_Finnish/SL/SL1/0.txt
#   inflating: training_18M_without_Finnish/SL/SL1/1.txt
#   inflating: training_18M_without_Finnish/SL/SL1/2.txt
#   inflating: training_18M_without_Finnish/SL/SL1/3.txt
#   inflating: training_18M_without_Finnish/SL/SL1/4.txt
#   inflating: training_18M_without_Finnish/SL/SL1/5.txt
#   inflating: training_18M_without_Finnish/SL/SL1/6.txt
#   inflating: training_18M_without_Finnish/SL/SL1/7.txt
#   inflating: training_18M_without_Finnish/SL/SL1/8.txt
#   inflating: training_18M_without_Finnish/SL/SL1/9.txt
#   inflating: training_18M_without_Finnish/SL/SL1/10.txt
#   inflating: training_18M_without_Finnish/SL/SL1/11.txt
#   inflating: training_18M_without_Finnish/SL/SL1/12.txt
#   inflating: training_18M_without_Finnish/SL/SL1/13.txt
#   inflating: training_18M_without_Finnish/SL/SL1/14.txt
#   inflating: training_18M_without_Finnish/SL/SL1/15.txt
#   inflating: training_18M_without_Finnish/SL/SL1/16.txt
#   inflating: training_18M_without_Finnish/SL/SL1/17.txt
#   inflating: training_18M_without_Finnish/SL/SL1/18.txt
#   inflating: training_18M_without_Finnish/SL/SL1/19.txt
#   inflating: training_18M_without_Finnish/SL/SL1/20.txt
#   inflating: training_18M_without_Finnish/SL/SL1/21.txt
#   inflating: training_18M_without_Finnish/SL/SL1/22.txt
#   inflating: training_18M_without_Finnish/SL/SL1/23.txt
#   inflating: training_18M_without_Finnish/SL/SL1/24.txt
#   inflating: training_18M_without_Finnish/SL/SL1/25.txt
#   inflating: training_18M_without_Finnish/SL/SL1/26.txt
#   inflating: training_18M_without_Finnish/SL/SL1/27.txt
#   inflating: training_18M_without_Finnish/SL/SL1/28.txt
#   inflating: training_18M_without_Finnish/SL/SL1/29.txt
#   inflating: training_18M_without_Finnish/SL/SL1/30.txt
#   inflating: training_18M_without_Finnish/SL/SL1/31.txt
#   inflating: training_18M_without_Finnish/SL/SL1/32.txt
#   inflating: training_18M_without_Finnish/SL/SL1/33.txt
#   inflating: training_18M_without_Finnish/SL/SL1/34.txt
#   inflating: training_18M_without_Finnish/SL/SL1/35.txt
#   inflating: training_18M_without_Finnish/SL/SL1/36.txt
#   inflating: training_18M_without_Finnish/SL/SL1/37.txt
#   inflating: training_18M_without_Finnish/SL/SL1/38.txt
#   inflating: training_18M_without_Finnish/SL/SL1/39.txt
#   inflating: training_18M_without_Finnish/SL/SL1/40.txt
#   inflating: training_18M_without_Finnish/SL/SL1/41.txt
#   inflating: training_18M_without_Finnish/SL/SL1/42.txt
#   inflating: training_18M_without_Finnish/SL/SL1/43.txt
#   inflating: training_18M_without_Finnish/SL/SL1/44.txt
#   inflating: training_18M_without_Finnish/SL/SL1/45.txt
#   inflating: training_18M_without_Finnish/SL/SL1/46.txt
#   inflating: training_18M_without_Finnish/SL/SL1/47.txt
#   inflating: training_18M_without_Finnish/SL/SL1/48.txt
#   inflating: training_18M_without_Finnish/SL/SL1/49.txt
#   inflating: training_18M_without_Finnish/SL/SL1/50.txt
#   inflating: training_18M_without_Finnish/SL/SL1/51.txt
#   inflating: training_18M_without_Finnish/SL/SL1/52.txt
#   inflating: training_18M_without_Finnish/SL/SL1/53.txt
#   inflating: training_18M_without_Finnish/SL/SL1/54.txt
#   inflating: training_18M_without_Finnish/SL/SL1/55.txt
#   inflating: training_18M_without_Finnish/SL/SL1/56.txt
#   inflating: training_18M_without_Finnish/SL/SL1/57.txt
#   inflating: training_18M_without_Finnish/SL/SL1/58.txt
#   inflating: training_18M_without_Finnish/SL/SL1/59.txt
#   inflating: training_18M_without_Finnish/SL/SL1/60.txt
#   inflating: training_18M_without_Finnish/SL/SL1/61.txt
#   inflating: training_18M_without_Finnish/SL/SL1/62.txt
#   inflating: training_18M_without_Finnish/SL/SL1/63.txt
#   inflating: training_18M_without_Finnish/SL/SL1/64.txt
#   inflating: training_18M_without_Finnish/SL/SL1/65.txt
#   inflating: training_18M_without_Finnish/SL/SL1/66.txt
#   inflating: training_18M_without_Finnish/SL/SL1/67.txt
#   inflating: training_18M_without_Finnish/SL/SL1/68.txt
#   inflating: training_18M_without_Finnish/SL/SL1/69.txt
#   inflating: training_18M_without_Finnish/SL/SL1/70.txt
#   inflating: training_18M_without_Finnish/SL/SL1/71.txt
#   inflating: training_18M_without_Finnish/SL/SL1/72.txt
#   inflating: training_18M_without_Finnish/SL/SL1/73.txt
#   inflating: training_18M_without_Finnish/SL/SL1/74.txt
#   inflating: training_18M_without_Finnish/SL/SL1/75.txt
#   inflating: training_18M_without_Finnish/SL/SL1/76.txt
#   inflating: training_18M_without_Finnish/SL/SL1/77.txt
#   inflating: training_18M_without_Finnish/SL/SL1/78.txt
#   inflating: training_18M_without_Finnish/SL/SL1/79.txt
#   inflating: training_18M_without_Finnish/SL/SL1/80.txt
#   inflating: training_18M_without_Finnish/SL/SL1/81.txt
#   inflating: training_18M_without_Finnish/SL/SL1/82.txt
#   inflating: training_18M_without_Finnish/SL/SL1/83.txt
#   inflating: training_18M_without_Finnish/SL/SL1/84.txt
#   inflating: training_18M_without_Finnish/SL/SL1/85.txt
#   inflating: training_18M_without_Finnish/SL/SL1/86.txt
#   inflating: training_18M_without_Finnish/SL/SL1/87.txt
#   inflating: training_18M_without_Finnish/SL/SL1/88.txt
#   inflating: training_18M_without_Finnish/SL/SL1/89.txt
#   inflating: training_18M_without_Finnish/SL/SL1/90.txt
#   inflating: training_18M_without_Finnish/SL/SL1/91.txt
#   inflating: training_18M_without_Finnish/SL/SL1/92.txt
#   inflating: training_18M_without_Finnish/SL/SL1/93.txt
#   inflating: training_18M_without_Finnish/SL/SL1/94.txt
#   inflating: training_18M_without_Finnish/SL/SL1/95.txt
#   inflating: training_18M_without_Finnish/SL/SL1/96.txt
#   inflating: training_18M_without_Finnish/SL/SL1/97.txt
#   inflating: training_18M_without_Finnish/SL/SL1/98.txt
#   inflating: training_18M_without_Finnish/SL/SL1/99.txt
#   inflating: training_18M_without_Finnish/SL/SL1/100.txt
#   inflating: training_18M_without_Finnish/SL/SL1/101.txt
#   inflating: training_18M_without_Finnish/SL/SL1/102.txt
#   inflating: training_18M_without_Finnish/SL/SL1/103.txt
#   inflating: training_18M_without_Finnish/SL/SL1/104.txt
#   inflating: training_18M_without_Finnish/SL/SL1/105.txt
#   inflating: training_18M_without_Finnish/SL/SL1/106.txt
#   inflating: training_18M_without_Finnish/SL/SL1/107.txt
#   inflating: training_18M_without_Finnish/SL/SL1/108.txt
#   inflating: training_18M_without_Finnish/SL/SL1/109.txt
#   inflating: training_18M_without_Finnish/SL/SL1/110.txt
#   inflating: training_18M_without_Finnish/SL/SL1/111.txt
#   inflating: training_18M_without_Finnish/SL/SL1/112.txt
#   inflating: training_18M_without_Finnish/SL/SL1/113.txt
#   inflating: training_18M_without_Finnish/SL/SL1/114.txt
#   inflating: training_18M_without_Finnish/SL/SL1/115.txt
#   inflating: training_18M_without_Finnish/SL/SL1/116.txt
#   inflating: training_18M_without_Finnish/SL/SL1/117.txt
#   inflating: training_18M_without_Finnish/SL/SL1/118.txt
#   inflating: training_18M_without_Finnish/SL/SL1/119.txt
#   inflating: training_18M_without_Finnish/SL/SL1/120.txt
#   inflating: training_18M_without_Finnish/SL/SL1/121.txt
#   inflating: training_18M_without_Finnish/SL/SL1/122.txt
#   inflating: training_18M_without_Finnish/SL/SL1/123.txt
#   inflating: training_18M_without_Finnish/SL/SL1/124.txt
#   inflating: training_18M_without_Finnish/SL/SL1/125.txt
#   inflating: training_18M_without_Finnish/SL/SL1/126.txt
#   inflating: training_18M_without_Finnish/SL/SL1/127.txt
#   inflating: training_18M_without_Finnish/SL/SL1/128.txt
#   inflating: training_18M_without_Finnish/SL/SL1/129.txt
#   inflating: training_18M_without_Finnish/SL/SL1/130.txt
#   inflating: training_18M_without_Finnish/SL/SL1/131.txt
#   inflating: training_18M_without_Finnish/SL/SL1/132.txt
#   inflating: training_18M_without_Finnish/SL/SL1/133.txt
#   inflating: training_18M_without_Finnish/SL/SL1/134.txt
#   inflating: training_18M_without_Finnish/SL/SL1/135.txt
#   inflating: training_18M_without_Finnish/SL/SL1/136.txt
#   inflating: training_18M_without_Finnish/SL/SL1/137.txt
#   inflating: training_18M_without_Finnish/SL/SL1/138.txt
#   inflating: training_18M_without_Finnish/SL/SL1/139.txt
#   inflating: training_18M_without_Finnish/SL/SL1/140.txt
#   inflating: training_18M_without_Finnish/SL/SL1/141.txt
#   inflating: training_18M_without_Finnish/SL/SL1/142.txt
#   inflating: training_18M_without_Finnish/SL/SL1/143.txt
#   inflating: training_18M_without_Finnish/SL/SL1/144.txt
#   inflating: training_18M_without_Finnish/SL/SL1/145.txt
#   inflating: training_18M_without_Finnish/SL/SL1/146.txt
#   inflating: training_18M_without_Finnish/SL/SL1/147.txt
#   inflating: training_18M_without_Finnish/SL/SL1/148.txt

# %%
#re-used pre-processing functions

def remove_ext(fname):
    """Removes the extension from a filename
    """
    bn = os.path.basename(fname)
    return os.path.splitext(bn)[0]


def create_dirs(fname, is_file=False):
    """Create (output) directories if they don't exist

    Removes the file name part if is_file is set to True.
    """
    fname = os.path.abspath(fname)
    if is_file:
        fname = os.path.dirname(fname)

    if not os.path.exists(fname):
        os.makedirs(fname)


def out_file_name(out_dir, fname, ext=None):
    """Return path of output file, given a directory, file name and extension.

    If fname is a path, it is converted to its basename.

    Args:
        out_dir (str): path to the directory where output should be written.
        fname (str): path to the input file.
        ext (str): file extension of the output file (defaults to None).

    Returns:
        str: out_dir + fname with extension replaced. If `ext` is `None`, the
            original extension is kept.
    """
    if ext is None:
        return os.path.join(out_dir, os.path.basename(fname))

    fname = remove_ext(fname)
    return os.path.join(out_dir, '{}.{}'.format(fname, ext))


def cwl_file(fname):
    return {'class': 'File', 'path': fname}


def get_files(directory, recursive=False):
    """Return a list of all files in the directory."""
    files_out = []
    if recursive:
        for root, dirs, files in os.walk(os.path.abspath(directory)):
            files = [os.path.join(root, f) for f in files]
            files_out.append(files)
        files_out = list(itertools.chain(*files_out))
    else:
        files_out = [os.path.join(directory, f) for f in os.listdir(directory)]
        files_out = list(filter(lambda f: os.path.isfile(f), files_out))

    # order alphabetically on file name
    return sorted(files_out)


def split(s):
    return s.split()


def read_xml(fname):
    with codecs.open(fname, encoding='utf-8') as f:
        xml = f.read()
    return BeautifulSoup(xml, 'xml')


def write_xml(soup, fname):
    with codecs.open(fname, 'wb', encoding='utf-8') as f:
        
        f.write(str(soup))

# %%
in_dir = './evaluation_4M_without_Finnish/DE/DE2'
out_dir = 'DE_2'

def command(in_file, out_dir):
    create_dirs(out_dir)

    lines = in_file.readlines()
    # OCR_toInput: lines[0][:14]
    # OCR_aligned: lines[1][:14]
    # GS_aligned: lines[2][:14]
    ocr = to_character_list(lines[1][14:].strip())
    gs = to_character_list(lines[2][14:].strip())

    # Write texts
    out_file = out_file_name(os.path.join(out_dir, 'ocr'), os.path.basename(in_file.name))
    print(out_file)
    create_dirs(out_file, is_file=True)
    with codecs.open(out_file, 'wb', encoding='utf-8') as f:
        f.write(u''.join(ocr))

    out_file = out_file_name(os.path.join(out_dir, 'gs'), os.path.basename(in_file.name))
    print(out_file)
    create_dirs(out_file, is_file=True)
    with codecs.open(out_file, 'wb', encoding='utf-8') as f:
        f.write(u''.join(gs))

    out_file = out_file_name(os.path.join(out_dir, 'aligned'), os.path.basename(in_file.name), 'json')
    print(out_file)
    create_dirs(out_file, is_file=True)
    with codecs.open(out_file, 'wb', encoding='utf-8') as f:
        json.dump({'ocr': ocr, 'gs': gs}, f)
        
    
in_files = get_files(in_dir)
for in_file in in_files:
    print(in_file)
    
    command(open(in_file), out_dir)
# Out:
# ./evaluation_4M_without_Finnish/DE/DE2/0.txt
# DE_2/ocr/0.txt
# DE_2/gs/0.txt
# DE_2/aligned/0.json
# ./evaluation_4M_without_Finnish/DE/DE2/1.txt
# DE_2/ocr/1.txt
# DE_2/gs/1.txt
# DE_2/aligned/1.json
# ./evaluation_4M_without_Finnish/DE/DE2/10.txt
# DE_2/ocr/10.txt
# DE_2/gs/10.txt
# DE_2/aligned/10.json
# ./evaluation_4M_without_Finnish/DE/DE2/11.txt
# DE_2/ocr/11.txt
# DE_2/gs/11.txt
# DE_2/aligned/11.json
# ./evaluation_4M_without_Finnish/DE/DE2/12.txt
# DE_2/ocr/12.txt
# DE_2/gs/12.txt
# DE_2/aligned/12.json
# ./evaluation_4M_without_Finnish/DE/DE2/13.txt
# DE_2/ocr/13.txt
# DE_2/gs/13.txt
# DE_2/aligned/13.json
# ./evaluation_4M_without_Finnish/DE/DE2/14.txt
# DE_2/ocr/14.txt
# DE_2/gs/14.txt
# DE_2/aligned/14.json
# ./evaluation_4M_without_Finnish/DE/DE2/15.txt
# DE_2/ocr/15.txt
# DE_2/gs/15.txt
# DE_2/aligned/15.json
# ./evaluation_4M_without_Finnish/DE/DE2/16.txt
# DE_2/ocr/16.txt
# DE_2/gs/16.txt
# DE_2/aligned/16.json
# ./evaluation_4M_without_Finnish/DE/DE2/17.txt
# DE_2/ocr/17.txt
# DE_2/gs/17.txt
# DE_2/aligned/17.json
# ./evaluation_4M_without_Finnish/DE/DE2/18.txt
# DE_2/ocr/18.txt
# DE_2/gs/18.txt
# DE_2/aligned/18.json
# ./evaluation_4M_without_Finnish/DE/DE2/19.txt
# DE_2/ocr/19.txt
# DE_2/gs/19.txt
# DE_2/aligned/19.json
# ./evaluation_4M_without_Finnish/DE/DE2/2.txt
# DE_2/ocr/2.txt
# DE_2/gs/2.txt
# DE_2/aligned/2.json
# ./evaluation_4M_without_Finnish/DE/DE2/20.txt
# DE_2/ocr/20.txt
# DE_2/gs/20.txt
# DE_2/aligned/20.json
# ./evaluation_4M_without_Finnish/DE/DE2/21.txt
# DE_2/ocr/21.txt
# DE_2/gs/21.txt
# DE_2/aligned/21.json
# ./evaluation_4M_without_Finnish/DE/DE2/22.txt
# DE_2/ocr/22.txt
# DE_2/gs/22.txt
# DE_2/aligned/22.json
# ./evaluation_4M_without_Finnish/DE/DE2/23.txt
# DE_2/ocr/23.txt
# DE_2/gs/23.txt
# DE_2/aligned/23.json
# ./evaluation_4M_without_Finnish/DE/DE2/24.txt
# DE_2/ocr/24.txt
# DE_2/gs/24.txt
# DE_2/aligned/24.json
# ./evaluation_4M_without_Finnish/DE/DE2/25.txt
# DE_2/ocr/25.txt
# DE_2/gs/25.txt
# DE_2/aligned/25.json
# ./evaluation_4M_without_Finnish/DE/DE2/26.txt
# DE_2/ocr/26.txt
# DE_2/gs/26.txt
# DE_2/aligned/26.json
# ./evaluation_4M_without_Finnish/DE/DE2/27.txt
# DE_2/ocr/27.txt
# DE_2/gs/27.txt
# DE_2/aligned/27.json
# ./evaluation_4M_without_Finnish/DE/DE2/28.txt
# DE_2/ocr/28.txt
# DE_2/gs/28.txt
# DE_2/aligned/28.json
# ./evaluation_4M_without_Finnish/DE/DE2/29.txt
# DE_2/ocr/29.txt
# DE_2/gs/29.txt
# DE_2/aligned/29.json
# ./evaluation_4M_without_Finnish/DE/DE2/3.txt
# DE_2/ocr/3.txt
# DE_2/gs/3.txt
# DE_2/aligned/3.json
# ./evaluation_4M_without_Finnish/DE/DE2/30.txt
# DE_2/ocr/30.txt
# DE_2/gs/30.txt
# DE_2/aligned/30.json
# ./evaluation_4M_without_Finnish/DE/DE2/31.txt
# DE_2/ocr/31.txt
# DE_2/gs/31.txt
# DE_2/aligned/31.json
# ./evaluation_4M_without_Finnish/DE/DE2/32.txt
# DE_2/ocr/32.txt
# DE_2/gs/32.txt
# DE_2/aligned/32.json
# ./evaluation_4M_without_Finnish/DE/DE2/33.txt
# DE_2/ocr/33.txt
# DE_2/gs/33.txt
# DE_2/aligned/33.json
# ./evaluation_4M_without_Finnish/DE/DE2/34.txt
# DE_2/ocr/34.txt
# DE_2/gs/34.txt
# DE_2/aligned/34.json
# ./evaluation_4M_without_Finnish/DE/DE2/35.txt
# DE_2/ocr/35.txt
# DE_2/gs/35.txt
# DE_2/aligned/35.json
# ./evaluation_4M_without_Finnish/DE/DE2/36.txt
# DE_2/ocr/36.txt
# DE_2/gs/36.txt
# DE_2/aligned/36.json
# ./evaluation_4M_without_Finnish/DE/DE2/37.txt
# DE_2/ocr/37.txt
# DE_2/gs/37.txt
# DE_2/aligned/37.json
# ./evaluation_4M_without_Finnish/DE/DE2/38.txt
# DE_2/ocr/38.txt
# DE_2/gs/38.txt
# DE_2/aligned/38.json
# ./evaluation_4M_without_Finnish/DE/DE2/39.txt
# DE_2/ocr/39.txt
# DE_2/gs/39.txt
# DE_2/aligned/39.json
# ./evaluation_4M_without_Finnish/DE/DE2/4.txt
# DE_2/ocr/4.txt
# DE_2/gs/4.txt
# DE_2/aligned/4.json
# ./evaluation_4M_without_Finnish/DE/DE2/40.txt
# DE_2/ocr/40.txt
# DE_2/gs/40.txt
# DE_2/aligned/40.json
# ./evaluation_4M_without_Finnish/DE/DE2/41.txt
# DE_2/ocr/41.txt
# DE_2/gs/41.txt
# DE_2/aligned/41.json
# ./evaluation_4M_without_Finnish/DE/DE2/42.txt
# DE_2/ocr/42.txt
# DE_2/gs/42.txt
# DE_2/aligned/42.json
# ./evaluation_4M_without_Finnish/DE/DE2/43.txt
# DE_2/ocr/43.txt
# DE_2/gs/43.txt
# DE_2/aligned/43.json
# ./evaluation_4M_without_Finnish/DE/DE2/44.txt
# DE_2/ocr/44.txt
# DE_2/gs/44.txt
# DE_2/aligned/44.json
# ./evaluation_4M_without_Finnish/DE/DE2/45.txt
# DE_2/ocr/45.txt
# DE_2/gs/45.txt
# DE_2/aligned/45.json
# ./evaluation_4M_without_Finnish/DE/DE2/46.txt
# DE_2/ocr/46.txt
# DE_2/gs/46.txt
# DE_2/aligned/46.json
# ./evaluation_4M_without_Finnish/DE/DE2/47.txt
# DE_2/ocr/47.txt
# DE_2/gs/47.txt
# DE_2/aligned/47.json
# ./evaluation_4M_without_Finnish/DE/DE2/48.txt
# DE_2/ocr/48.txt
# DE_2/gs/48.txt
# DE_2/aligned/48.json
# ./evaluation_4M_without_Finnish/DE/DE2/49.txt
# DE_2/ocr/49.txt
# DE_2/gs/49.txt
# DE_2/aligned/49.json
# ./evaluation_4M_without_Finnish/DE/DE2/5.txt
# DE_2/ocr/5.txt
# DE_2/gs/5.txt
# DE_2/aligned/5.json
# ./evaluation_4M_without_Finnish/DE/DE2/6.txt
# DE_2/ocr/6.txt
# DE_2/gs/6.txt
# DE_2/aligned/6.json
# ./evaluation_4M_without_Finnish/DE/DE2/7.txt
# DE_2/ocr/7.txt
# DE_2/gs/7.txt
# DE_2/aligned/7.json
# ./evaluation_4M_without_Finnish/DE/DE2/8.txt
# DE_2/ocr/8.txt
# DE_2/gs/8.txt
# DE_2/aligned/8.json
# ./evaluation_4M_without_Finnish/DE/DE2/9.txt
# DE_2/ocr/9.txt
# DE_2/gs/9.txt
# DE_2/aligned/9.json

# %% [markdown]
# ## Our Annotated Sample

# %%
data_dir='annots_csv'
annots=[]
for n, file in enumerate(os.listdir(data_dir),1):

    if file.endswith('csv'):
        with open(os.path.join(data_dir, file), 'r') as f:
            print(file)
            annots+=[pd.read_csv(f, delimiter=';')]

# %%
data_actd = pd.concat([annots[1][annots[1].loc[:,"edited-reading_order"].isna() != True],
annots[0][annots[0].loc[:,"edited-reading_order"].isna() != True]],axis=0)

# %%
data_actd=data_actd.drop(columns=['Diabetiker_journal_blocks_OCR', 'complexity_type', 'Unnamed: 0'])
data_actd_grouped = data_actd.groupby(['year','nr','page'])[['block_text', 'edited-reading_order']].agg(list).reset_index()

# %%
data_actd_grouped['block_text']=data_actd_grouped.block_text.apply(lambda t: '\n'.join(t))
data_actd_grouped['edited-reading_order']=data_actd_grouped['edited-reading_order'].apply(lambda t: '\n'.join(t))

# %% [markdown]
# ### Add Old Annotations

# %%
data_dir = "corrected_ocr_old"
dfs=[]
for n, file in enumerate(os.listdir(data_dir),1):

    if file.endswith('noro.txt'):
        
        base_ocr_file = ''.join(file.split('_noro'))
        with open(os.path.join(data_dir, file), 'r') as f:
            gs_ocr=f.read()
        with open(os.path.join(data_dir, base_ocr_file), 'r') as f:
            base_ocr=f.read()
        
        df=pd.DataFrame([(base_ocr, gs_ocr)], columns = ['ocr','gs'])
        df['source']=file.split('_noro')[0]
        dfs+=[df]

df_add = pd.concat(dfs,axis=0).query('ocr != ""')

# %% [markdown]
# ## Align GT and OCR (edlib)

# %%
os.makedirs("DJ_aligned", exist_ok=True)

def align_pages(df, out_file):
    query=df['ocr']
    ref=df['gt']
    # query=df.block_text
    # ref=df['edited-reading_order']
    a = edlib.align(query, ref, task="path")
    # code from
    ref_pos = a["locations"][0][0]
    query_pos = 0
    ref_aln = []
    match_aln = ""
    query_aln = []

    for step, code in re.findall(r"(\d+)(\D)", a["cigar"]):
        step = int(step)
        if code == "=":
            for c in ref[ref_pos: ref_pos + step]:
                ref_aln.append(c)
            #ref_aln += ref[ref_pos : ref_pos + step]
            ref_pos += step
            for c in query[query_pos: query_pos + step]:
                query_aln.append(c)
            #query_aln += query[query_pos : query_pos + step]
            query_pos += step
            match_aln += "|" * step
        elif code == "X":
            for c in ref[ref_pos: ref_pos + step]:
                ref_aln.append(c)
            #ref_aln += ref[ref_pos : ref_pos + step]
            ref_pos += step
            for c in query[query_pos: query_pos + step]:
                query_aln.append(c)
            #query_aln += query[query_pos : query_pos + step]
            query_pos += step
            match_aln += "." * step
        elif code == "D":
            for c in ref[ref_pos: ref_pos + step]:
                ref_aln.append(c)
            #ref_aln += ref[ref_pos : ref_pos + step]
            ref_pos += step
            #query_aln += " " * step
            query_pos += 0
            for i in range(step):
                query_aln.append('')
            match_aln += " " * step
        elif code == "I":
            for i in range(step):
                ref_aln.append('')
            #ref_aln += " " * step
            ref_pos += 0
            for c in query[query_pos: query_pos + step]:
                query_aln.append(c)
            #query_aln += query[query_pos : query_pos + step]
            query_pos += step
            match_aln += " " * step
        else:
            pass
    
    with codecs.open(out_file, 'wb', encoding='utf-8') as f:
        try:
            json.dump({'ocr': query_aln, 'gs': ref_aln}, f, encoding='utf-8')
        except TypeError:
            json.dump({'ocr': query_aln, 'gs': ref_aln}, f)


out_file='DJ_aligned/'+df.source+'.json'
data_actd_grouped.apply(lambda df: align_pages(df, out_file),axis=1)
out_file='DJ_aligned/'+str(int(df.year))+'__'+df.nr+'__'+str(int(df.page))+'.json'
df_add.apply(lambda df: align_pages(df, out_file),axis=1)

# %% [markdown]
# ## Process Aligned Dataset

# %%
def get_split_indices(chars, max_length=1000, delimiters={'.', ';'}):
    split_indices = []
    temp_sublist = []
    
    i = 0
    while i < len(chars):
        temp_sublist.append(chars[i])
        
        if len(temp_sublist) >= max_length:
            # Check if a split point exists in the nearby range
            found_split_point = False
            for j in range(i, min(i + 100, len(chars))):
                if chars[j] in delimiters:
                    # Record the index of the delimiter for splitting
                    split_indices.append(j)
                    temp_sublist = []  # Reset for the next sublist
                    i = j  # Continue from after the delimiter
                    found_split_point = True
                    break
            
            # If no split point was found, add a split at max_length
            if not found_split_point:
                split_indices.append(i)
                temp_sublist = []

        i += 1

    return split_indices

# %%
data_dirs = ["DE_1/aligned", "DE_2/aligned", "DJ_aligned"]
sources = ["Neue_Zürcher_Zeitung(NZZ)", "German National Library", "Diabetiker Journal"]
dfs=[]
# data_dir = "DE_1/aligned"
# data_dir  = "DE_2/aligned"
# data_dir  = "DJ_aligned"
for n, data_dir, source in enumerate(zip(data_dirs, sources)):

   
    for file in os.listdir(data_dir):
        f_id = file.split('.')[0]
        if file.endswith('.json'):
            with open(os.path.join(data_dir, file), encoding='utf-8') as f:
                d = json.load(f)
                
                d['gs']=["¬" if element == "⸗" else element for element in d['gs']]
                
                # identify gs indices to split on
                max_length=150
                indices=get_split_indices(d['gs'], max_length=max_length, delimiters={'\n'})#'.', ';',
                spans_gs = [''.join(d['gs'][i+1:j]) for i,j in zip(indices, indices[1:])]
                spans_ocr = [''.join(d['ocr'][i+1:j]) for i,j in zip(indices, indices[1:])]
                # spans_gs = [''.join(d['gs'])]
                # spans_ocr = [''.join(d['ocr'])]

                dfs+=[pd.DataFrame(zip([source]*len(spans_ocr), [f_id]*len(spans_ocr), spans_ocr, spans_gs), columns=['source','file_id','ocr','gs'])]

                # dfs+=[pd.DataFrame(zip(["Neue_Zürcher_Zeitung(NZZ)"]*len(spans_ocr), [f_id]*len(spans_ocr), spans_ocr, spans_gs), columns=['source','file_id','ocr','gs'])]
                # dfs+=[pd.DataFrame(zip(["Diabetiker_journal"]*len(spans_ocr), [f_id]*len(spans_ocr), spans_ocr, spans_gs), columns=['source','file_id','ocr','gs'])]
                # dfs+=[pd.DataFrame(zip(["German_National_Library"]*len(spans_ocr), [f_id]*len(spans_ocr), spans_ocr, spans_gs), columns=['source','file_id','ocr','gs'])]

# %%
# data_GNL = pd.concat(dfs, axis=0)
# data_ICDAR = pd.concat(dfs, axis=0)
# data_DJ = pd.concat(dfs, axis=0).reset_index(drop=True)

# %% [markdown]
# ## Merge the Dataframes

# %%
# dataset = pd.concat([data_ICDAR, data_DJ, data_GNL], axis=0)
dataset = pd.concat(dfs, axis=0)
print(f'max len of gs string: {dataset.gs.map(len).max()}')
dataset.columns=['Publication', 'file_id', 'OCR Text', 'Ground Truth','CER']

# %% [markdown]
# ## Calculate CER

# %%
# Compute character error rate (CER)
def cer(prediction, target):
    distance = Levenshtein.distance(prediction, target)
    return distance / len(target)

dataset['CER'] = dataset.apply(lambda row: cer(row['Ground Truth'], row['OCR Text']), axis=1)

# %% [markdown]
# ## Train-test Split

# %%
def assign_CER_interval(df):

    if df.CER >= 0.1:
        interval = '>=0.1'
    elif df.CER < 0.1 and df.CER != 0:
        interval = '<0.1&!=0'
    elif df.CER == 0:
        interval = '0'

    return interval


dataset['CER_interval'] = dataset.apply(assign_CER_interval,axis=1)

# %%
from sklearn.model_selection import train_test_split

train, valid = train_test_split(
    dataset.query("Publication in ['Diabetiker_journal']"),
    test_size=0.1,
    shuffle=True,
    stratify=dataset.query("Publication in ['Diabetiker_journal']")['CER_interval'],
    random_state=42
)
